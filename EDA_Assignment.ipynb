# %% [markdown]
# #EDA - 1:-

# %% [markdown]
# 1. What is the range of selling prices in the dataset?
#   - Minimum Selling Price: ₹5,000
#
#     Maximum Selling Price: ₹7,60,000
#
#     Range: ₹5,000 to ₹7,60,000
#
# 2. What is the median selling price for bikes in the dataset?
#   - Median Selling Price: ₹45,000
#
# 3. What is the most common seller type?
#   - Most Common Seller Type: Individual
#
#     1,055 out of 1,061 bikes are listed by individuals.
#
# 4. How many bikes have driven more than 50,000 kilometers?
#   - Number of Bikes: 170
#
# 5. What is the average km_driven value for each ownership type?
#    - Owner Type	Average km_driven
#
#     1st owner	32,816 km
#
#     2nd owner	39,289 km
#
#     3rd owner	33,292 km
#
#     4th owner	3,11,500 km
#
#   - The 4th owner value is suspiciously high and might be an outlier.
#
# 6. What proportion of bikes are from the year 2015 or older?
#   - Proportion: 56.6%
#
#     (Approximately 601 bikes out of 1,061 are from 2015 or earlier.)
#
# 7. What is the trend of missing values across the dataset?
#
#     | Column              |   Missing Values         |
#
#     | ------------------- | ---------------------- |
#
#     | `ex_showroom_price` | **435** missing values |
#
#     | All other columns   | 0 missing values       |
#
#
# 8. What is the highest ex_showroom_price recorded, and for which bike?
#   - Highest Ex-Showroom Price: ₹12,78,000
#
#   - Bike Model: Harley-Davidson Street Bob
#
# 9. What is the total number of bikes listed by each seller type?
#    | Seller Type | Count |
#
#    | ----------- | ----- |
#
#    | Individual  | 1,055 |
#
#    | Dealer      | 6     |
#
# 10. What is the relationship between selling_price and km_driven for first-owner bikes?
#  - Correlation coefficient: −0.24
#
#      This indicates a weak negative correlation, meaning that as the kilometers driven increase, the selling price tends to slightly decrease, but not strongly.
#
# 11. Identify and remove outliers in the km_driven column using the IQR method
#    - Outliers Removed: 39 entries
#
#      These are bikes with exceptionally high or low kilometer values outside the IQR range.
#
# 12. Perform a bivariate analysis to visualize the relationship between year and selling_price
#
#    - | Year | Average Selling Price (₹) |
#
#      | ---- | ------------------------- |
#
#      | 2010 | 31,793                    |
#
#      | 2015 | 56,500                    |
#
#      | 2018 | 87,660                    |
#
#      | 2019 | 1,19,689                  |
#
#      | 2020 | 1,83,333                  |
#
#  - Trend: Newer bikes tend to fetch higher prices, as expected.
#
# 13. What is the average depreciation in selling price based on bike's age (2025 − year)?
#   - | Age (Years) | Average Depreciation (₹)                    |
#
#      | ----------- | ------------------------------------------- |
#
#      | 5           | -27,593 *(possibly underpriced used bikes)* |
#
#      | 6           | -5,610                                      |
#
#      | 10          | 26,063                                      |
#
#      | 14          | 48,235                                      |
#
#      | 18          | 42,455                                      |
#
#
#    - Negative depreciation implies selling prices higher than showroom prices, possibly due to incomplete/missing showroom data or special editions.
#
# 14. Which bike names are priced significantly above the average price for their manufacturing year?
#   - These bikes are priced 50% or more above the average for their year:
#
#      | Bike Name                        | Year | Price (₹) | Avg (₹) |
#
#      | -------------------------------- | ---- | --------- | ------- |
#
#      | Yamaha YZF R3                    | 2019 | 365000    | 119690  |
#
#      | Royal Enfield Continental GT 650 | 2019 | 299000    | 119690  |
#
#      | Suzuki GSX S750                  | 2019 | 760000    | 119690  |
#
#      | TVS Apache RR310                 | 2019 | 200000    | 119690  |
#
#
#   - These could be performance models, premium bikes, or mispriced entries.
#
# 15. Develop a correlation matrix for numeric columns and visualize it
#  -  | Feature             | Correlation with Selling Price |
#
#     | ------------------- | ------------------------------ |
#
#     | `year`              | +0.40 *(Moderate Positive)*    |
#
#     | `km_driven`         | -0.21 *(Weak Negative)*        |
#
#     | `ex_showroom_price` | +0.92 *(Strong Positive)*      |
#
#   - Insight: Ex-showroom price is the strongest predictor of resale price.
#   - More kilometers reduce the value slightly.

# %% [markdown]
# #EDA-2:-

# %% [markdown]
# 1. What is the average selling price of cars for each dealer, and how does it compare across different dealers?
#    - Answer:
#     Top 5 dealers with the highest average car prices:
#
#     - U-Haul CO: $28,769.92
#
#     - Classic Chevy: $28,602.01
#
#     - Rabun Used Car Sales: $28,527.54
#
#     - Iceberg Rentals: $28,522.96
#
#     - Enterprise Rent A Car: $28,312.58
#
# 2. Which car brand (Company) has the highest variation in prices, and what does this tell us about the pricing trends?
#    - Answer:
#     Top 5 companies with highest price standard deviation:
#
#     - Lincoln: $19,658.05
#
#     - Saab: $19,653.74
#
#     - Cadillac: $19,517.12
#
#     - Plymouth: $19,066.00
#
#     - Lexus: $17,852.92
#
#      These brands likely offer both premium and affordable models, causing higher variation.
#
# 3. What is the distribution of car prices for each transmission type, and how do the interquartile ranges compare?
#    - Answer:
#
#     - Automatic cars tend to have higher median prices than Manual.
#
#     - Both transmission types show a wide price range.
#
# 4. What is the distribution of car prices across different regions?
#   - Answer:
#     Average prices per region range from $27,833 to $28,341, showing slight regional variation.
#
# 5. What is the distribution of cars based on body styles?
#    - Answer:
#      Top body styles in the dataset:
#
#      - SUV: 6,374 cars
#
#      - Hatchback: 6,128 cars
#
#      - Sedan: 4,488 cars
#
#     SUVs and Hatchbacks dominate used car sales.
#
# 6. How does the average selling price of cars vary by customer gender and annual income?
#    -  | Gender | Avg. Annual Income | Avg. Price |
#
#       | ------ | ------------------ | ---------- |
#
#       | Female | \$755,973          | \$28,277   |
#
#       | Male   | \$851,184          | \$28,039   |
#
#     Female customers spend slightly more on average, despite having lower income.
#
# 7. What is the distribution of car prices by region, and how does the number of cars sold vary by region?
#    - | Region     | Avg. Price | Cars Sold |
#
#      | ---------- | ---------- | --------- |
#
#      | Austin     | \$28,341   | 4,135     |
#
#      | Janesville | \$27,833   | 3,821     |
#
#      | Scottsdale | \$27,955   | 3,433     |
#
#
#    - Austin shows both highest prices and most sales.
#
# 8. How does the average car price differ between cars with different engine sizes?
#    - | Engine Type              | Avg. Price |
#
#      | ------------------------ | ---------- |
#
#      | Double Overhead Camshaft | \$28,248   |
#
#      | Overhead Camshaft        | \$27,915   |
#
#   -  Double camshaft engines are slightly more expensive.
#
# 9. How do car prices vary based on the customer’s annual income bracket?
#   - | Income Bracket | Avg. Price |
#
#     | -------------- | ---------- |
#
#     | 0–50K          | \$27,884   |
#
#     | 100K–250K      | \$28,945   |
#
#     | 500K–1M        | \$28,011   |
#
#
#    - Prices are not strictly increasing with income — showing diverse customer behavior.
#
# 10. What are the top 5 car models with the highest number of sales, and how does their price distribution look?
#   - | Model      | Count |
#
#      | ---------- | ----- |
#
#      | Diamante   | 418   |
#
#      | Silhouette | 411   |
#
#      | Prizm      | 411   |
#
#    - Popular models are generally mid-range priced and frequently sold.
#
# 11. How does car price vary with engine size across different car colors, and which colors have the highest price variation?
#  -  Boxplot: Price vs Engine & Color
#
#  -  Black, Red, and Silver cars have the widest price range, often linked to premium models.
#
# 12. Is there any seasonal trend in car sales based on the date of sale?
#  -  Monthly Sales Count
#
#  - Slight rise in sales in January to March, likely influenced by year-end discounts or new models.
#
# 13. How does the car price distribution change with different combinations of body style and transmission type?
#  - Boxplot: Price by Body Style & Transmission
#
#  -  Automatic SUVs and Sedans fetch the highest average prices.
#  - Manual Hatchbacks are on the affordable side.
#
# 14. What is the correlation between car price, engine size, and annual income of customers, and how do these features interact?
#  - Heatmap: Correlation Matrix
#
#  - Weak correlation between Income and Price (~0.04)
#  -Engine type shows minimal influence on pricing
#
# 15. How does the average car price vary across different car models and engine types?
#  - Barplot: Top 10 Model + Engine Type Combos by Avg. Price
#
#  -  Models like Ram Pickup, Silverado, Explorer with Double Overhead Camshaft engines dominate premium price segments.

# %% [markdown]
# #EDA-3:-

# %% [markdown]
# Q1. What is the average rating for each product category?
#   - Example top-rated categories:
#
#     - Computers & Accessories | Tablets → 4.6
#
#     - Networking Devices | PowerLAN Adapters → 4.5
#
#     - Cameras & Photography | Accessories | Film → 4.5
#
#   - The average rating ranges from 3.3 to 4.6 depending on the category.
#
# Q2. What are the top rating_count products by category?
#   - The highest-rated product (by number of user ratings) in each category:
#
#     - Vacuum Cleaners: Eureka Forbes Car Vac → 992 ratings
#
#     - Batteries: Eveready Red AAA Batteries → 989 ratings
#
#     - Kettles: Pigeon Hot Kettle → 976 ratings
#
#   - These represent the most trusted products per category based on customer votes.
#
# Q3. What is the distribution of discounted prices vs. actual prices?
#  - | Metric | Discounted Price (₹) | Actual Price (₹) |
#
#      | ------ | -------------------- | ---------------- |
#
#      | Mean   | ₹3,125               | ₹5,445           |
#
#      | Median | ₹799                 | ₹1,650           |
#
#      | Max    | ₹77,990              | ₹1,39,900        |
#
#
#    - Prices are heavily right-skewed, with many products below ₹2,000 but some luxury items above ₹50,000.
#
# Q4. How does the average discount percentage vary across categories?
#   - Highest average discounts:
#
#      - Phone Charms → 90%
#
#      - Cable Protectors, Earpads → ~88–90%
#
#   - Some categories (e.g., Calculators, Film Rolls) show 0% discount, suggesting fixed pricing or no promotions.
#
# Q5. What are the most popular product names?
#   - Based on repetition in listings:
#
#      - Fire-Boltt Ninja Call Pro Plus Smartwatch → appears 5 times
#
#      - Fire-Boltt Phoenix Smartwatch → 4 times
#
#      - Other popular items include cables and chargers from AmazonBasics, MI, and boAt.
#
# Q6. What are the most popular product keywords?
#   - Top words from the “about_product” descriptions:
#
#      - and
#
#      - the
#
#      - to
#
#      - with
#
#      - for
#
#      - of
#
#      - a
#
#      - your
#
#      - in
#
#      - is
#
#     *Note: Removing stopwords would reveal more actionable product-related keywords (e.g., “charging”, “durable”, “compatible”).
#
# Q7. What are the most popular product reviews?
#    - Most repeated review titles include:
#
#      - Worked on iPhone 7 and didn’t work on XR
#
#      - Good one, Value for money, Charging is really fast
#
#      - Budget king, Just Buy it, Really nice product
#
# Q8. What is the correlation between discounted_price and rating?
#    - Correlation coefficient: 0.12
#
#    - Insight: Very weak positive correlation, meaning higher prices don’t necessarily lead to better ratings.
#
# Q9. What are the top 5 categories based on the highest ratings?
#   - | Rank | Category                | Avg. Rating       |      |     |
#
#   | ---- | ----------------------- | ----------------- | ---- | --- |
#
#   | 1    | Computers & Accessories | Tablets           | 4.6  |     |
#
#   | 2    | Networking Devices      | PowerLAN Adapters | 4.5  |     |
#
#   | 3    | Cameras & Photography   | Accessories       | Film | 4.5 |
#
#   | 4    | Media Streaming Devices | 4.5               |      |     |
#
#   | 5    | Calculators             | Basic             | 4.5  |     |
#
#
# Q10. Identify any potential areas for improvement or optimization based on the data analysis.
#  - Low-rated categories (e.g., Electric Grinders, Dust Covers) may indicate quality issues or customer dissatisfaction.
#
#  - Promote under-reviewed high-rated products to boost visibility.
#
#  - Streamline pricing: Some categories show high variance between actual and discounted prices, possibly confusing users.
#
#  - Keyword enhancement: Optimize product descriptions by highlighting value-added terms like "durable", "fast-charging", etc.

# %% [markdown]
# #EDA-4:-

# %% [markdown]
# 1. Read the dataframe, check null values if present then do the needful. Check duplicate rows, if present then do the needful.
#
#   - There are no null values in the dataset.
#
#   - There are 27 duplicate rows found.
#
#   - Action: It is recommended to drop the duplicates using:
#
#     spotify_df.drop_duplicates(inplace=True)
#
# 2. What is the distribution of popularity among the tracks in the dataset? Visualize it using a histogram.
#
#   - Popularity values range from 29 to 96.
#
#   - The distribution is right-skewed, with most tracks having popularity between 70 and 90.
#
#   - A few tracks fall in the low-popularity segment (below 50).
#
#   - A histogram was plotted to visualize this distribution.
#
# 3. Is there any relationship between the popularity and the duration of tracks? Explore this using a scatter plot.
#
#   - A scatter plot was used to compare popularity and duration.
#
#   - There is no strong relationship observed between track duration and popularity.
#
#   - Tracks of all durations (short and long) exhibit a wide range of popularity scores.
#
# 4. Which artist has the highest number of tracks in the dataset? Display the count of tracks for each artist using a countplot.
#
#  - The top artists by track count are:
#
# | Artist       | Number of Tracks |
# | ------------ | ---------------- |
# | Drake        | 20               |
# | Travis Scott | 12               |
# | 21 Savage    | 11               |
# | ¥\$          | 11               |
# | Lil Nas X    | 11               |
#
#   - A count plot was used to visualize the track count distribution across artists.
#
# 5. What are the top 5 least popular tracks in the dataset? Provide the artist name and track name for each.
#
# | Artist         | Track Name                    | Popularity |
# | -------------- | ----------------------------- | ---------- |
# | Pressa         | Attachments (feat. Coi Leray) | 29         |
# | Justin Bieber  | Intentions                    | 35         |
# | French Montana | Splash Brothers               | 44         |
# | French Montana | Splash Brothers (duplicate)   | 44         |
# | Lil Baby       | On Me - Remix                 | 47         |
#
#
#  - These tracks have the lowest popularity scores in the dataset.
#
# 6. Among the top 5 most popular artists, which artist has the highest popularity on average?
#
#  - Top 5 artists by track count were analyzed for average popularity:
#
# | Artist       | Average Popularity |
# | ------------ | ------------------ |
# | Travis Scott | 87.0               |
# | ¥\$          | 86.1               |
# | 21 Savage    | 84.2               |
# | Drake        | 83.5               |
# | Lil Nas X    | 76.1               |
#
#  - Travis Scott has the highest average track popularity among these artists.
#
# 7. For the top 5 most popular artists, what are their most popular tracks? List the track name for each artist.
#
# | Artist       | Most Popular Track                      | Popularity |
# | ------------ | --------------------------------------- | ---------- |
# | Travis Scott | FE!N (feat. Playboi Carti)              | 93         |
# | ¥\$          | CARNIVAL                                | 96         |
# | Drake        | Rich Baby Daddy (feat. Sexyy Red & SZA) | 92         |
# | 21 Savage    | redrum                                  | 96         |
# | Lil Nas X    | THATS WHAT I WANT                       | 81         |
#
#
#   - These tracks are the most popular offerings by each of the top 5 artists.
#
# 8. Visualize relationships between multiple numerical variables simultaneously using a pair plot.
#
#   - A pair plot was used to explore the relationship between Popularity and Duration (ms).
#
#   - The visualization confirms that there is no strong linear or non-linear correlation between these variables.
#
# 9. Does the duration of tracks vary significantly across different artists? Explore this visually using a box plot or violin plot.
#
#   - A box plot for the top 5 artists shows that:
#
#     - Drake and Travis Scott have tracks with the widest duration range.
#
#     - Lil Nas X tends to produce shorter tracks with a narrower duration range.
#
#   - This indicates that track duration does vary noticeably across artists.
#
# 10. How does the distribution of track popularity vary for different artists? Visualize this using a swarm plot or a violin plot.
#
#   - A violin plot of Popularity for the top 5 artists shows:
#
#      - Travis Scott and 21 Savage have high and consistent popularity.
#
#      - Drake shows a wider spread in popularity across tracks.
#
#      - Lil Nas X has lower median popularity compared to peers.
